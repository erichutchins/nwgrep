# %% [markdown]
# # nwgrep Highlighting with Pandas
#
# This notebook demonstrates highlighting matching rows in pandas DataFrames using `nwgrep`.
#
# When `highlight=True`, nwgrep returns a `pandas.Styler` object that displays matching rows with a yellow background in Jupyter notebooks.

# %%
from __future__ import annotations

import pandas as pd

from nwgrep import nwgrep, register_grep_accessor

# Create sample dataframe
df = pd.DataFrame(
    {
        "timestamp": ["2024-01-01", "2024-01-02", "2024-01-03", "2024-01-04"],
        "level": ["INFO", "ERROR", "WARN", "ERROR"],
        "message": [
            "Application started",
            "Database connection failed",
            "Slow query detected",
            "Retry attempt failed",
        ],
    }
)

print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#     timestamp  level                     message
# 0  2024-01-01   INFO         Application started
# 1  2024-01-02  ERROR  Database connection failed
# 2  2024-01-03   WARN         Slow query detected
# 3  2024-01-04  ERROR        Retry attempt failed

# %% [markdown]
# ## Basic Highlighting
#
# Highlight rows containing "ERROR" with a yellow background:

# %%
# Highlight matching rows
result = nwgrep(df, "ERROR", highlight=True)
result
# Out:
# <style type="text/css">
# #T_6e4aa_row0_col1, #T_6e4aa_row1_col1 {
#   background-color: #ffff99;
# }
# </style>
# <table id="T_6e4aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e4aa_level0_col0" class="col_heading level0 col0" >timestamp</th>
#       <th id="T_6e4aa_level0_col1" class="col_heading level0 col1" >level</th>
#       <th id="T_6e4aa_level0_col2" class="col_heading level0 col2" >message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e4aa_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6e4aa_row0_col0" class="data row0 col0" >2024-01-02</td>
#       <td id="T_6e4aa_row0_col1" class="data row0 col1" >ERROR</td>
#       <td id="T_6e4aa_row0_col2" class="data row0 col2" >Database connection failed</td>
#     </tr>
#     <tr>
#       <th id="T_6e4aa_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_6e4aa_row1_col0" class="data row1 col0" >2024-01-04</td>
#       <td id="T_6e4aa_row1_col1" class="data row1 col1" >ERROR</td>
#       <td id="T_6e4aa_row1_col2" class="data row1 col2" >Retry attempt failed</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Highlighting with Case-Insensitive Search
#
# Highlight rows with case-insensitive matching:

# %%
# Case-insensitive highlighting
result = nwgrep(df, "error", case_sensitive=False, highlight=True)
result
# Out:
# <style type="text/css">
# #T_264ad_row0_col1, #T_264ad_row1_col1 {
#   background-color: #ffff99;
# }
# </style>
# <table id="T_264ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_264ad_level0_col0" class="col_heading level0 col0" >timestamp</th>
#       <th id="T_264ad_level0_col1" class="col_heading level0 col1" >level</th>
#       <th id="T_264ad_level0_col2" class="col_heading level0 col2" >message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_264ad_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_264ad_row0_col0" class="data row0 col0" >2024-01-02</td>
#       <td id="T_264ad_row0_col1" class="data row0 col1" >ERROR</td>
#       <td id="T_264ad_row0_col2" class="data row0 col2" >Database connection failed</td>
#     </tr>
#     <tr>
#       <th id="T_264ad_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_264ad_row1_col0" class="data row1 col0" >2024-01-04</td>
#       <td id="T_264ad_row1_col1" class="data row1 col1" >ERROR</td>
#       <td id="T_264ad_row1_col2" class="data row1 col2" >Retry attempt failed</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Highlighting with Regex Patterns
#
# Highlight rows matching a regex pattern:

# %%
# Highlight rows with dates
result = nwgrep(df, r"\d{4}-\d{2}-\d{2}", regex=True, highlight=True)
result
# Out:
# <style type="text/css">
# #T_d6a8c_row0_col0, #T_d6a8c_row1_col0, #T_d6a8c_row2_col0, #T_d6a8c_row3_col0 {
#   background-color: #ffff99;
# }
# </style>
# <table id="T_d6a8c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6a8c_level0_col0" class="col_heading level0 col0" >timestamp</th>
#       <th id="T_d6a8c_level0_col1" class="col_heading level0 col1" >level</th>
#       <th id="T_d6a8c_level0_col2" class="col_heading level0 col2" >message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6a8c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6a8c_row0_col0" class="data row0 col0" >2024-01-01</td>
#       <td id="T_d6a8c_row0_col1" class="data row0 col1" >INFO</td>
#       <td id="T_d6a8c_row0_col2" class="data row0 col2" >Application started</td>
#     </tr>
#     <tr>
#       <th id="T_d6a8c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d6a8c_row1_col0" class="data row1 col0" >2024-01-02</td>
#       <td id="T_d6a8c_row1_col1" class="data row1 col1" >ERROR</td>
#       <td id="T_d6a8c_row1_col2" class="data row1 col2" >Database connection failed</td>
#     </tr>
#     <tr>
#       <th id="T_d6a8c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d6a8c_row2_col0" class="data row2 col0" >2024-01-03</td>
#       <td id="T_d6a8c_row2_col1" class="data row2 col1" >WARN</td>
#       <td id="T_d6a8c_row2_col2" class="data row2 col2" >Slow query detected</td>
#     </tr>
#     <tr>
#       <th id="T_d6a8c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d6a8c_row3_col0" class="data row3 col0" >2024-01-04</td>
#       <td id="T_d6a8c_row3_col1" class="data row3 col1" >ERROR</td>
#       <td id="T_d6a8c_row3_col2" class="data row3 col2" >Retry attempt failed</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Highlighting with Column Filtering
#
# Highlight rows where only specific columns match:

# %%
# Only search in the 'message' column
result = nwgrep(
    df, "connection", case_sensitive=False, columns=["message"], highlight=True
)
result
# Out:
# <style type="text/css">
# #T_02d28_row0_col2 {
#   background-color: #ffff99;
# }
# </style>
# <table id="T_02d28">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02d28_level0_col0" class="col_heading level0 col0" >timestamp</th>
#       <th id="T_02d28_level0_col1" class="col_heading level0 col1" >level</th>
#       <th id="T_02d28_level0_col2" class="col_heading level0 col2" >message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02d28_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_02d28_row0_col0" class="data row0 col0" >2024-01-02</td>
#       <td id="T_02d28_row0_col1" class="data row0 col1" >ERROR</td>
#       <td id="T_02d28_row0_col2" class="data row0 col2" >Database connection failed</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Using the Accessor
#
# You can also use the `.grep()` accessor with highlighting:

# %%
# Register the accessor
register_grep_accessor()

# Use df.grep() with highlighting
df.grep("failed", case_sensitive=False, highlight=True)
# Out:
# <style type="text/css">
# #T_f2d2e_row0_col2, #T_f2d2e_row1_col2 {
#   background-color: #ffff99;
# }
# </style>
# <table id="T_f2d2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2d2e_level0_col0" class="col_heading level0 col0" >timestamp</th>
#       <th id="T_f2d2e_level0_col1" class="col_heading level0 col1" >level</th>
#       <th id="T_f2d2e_level0_col2" class="col_heading level0 col2" >message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2d2e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f2d2e_row0_col0" class="data row0 col0" >2024-01-02</td>
#       <td id="T_f2d2e_row0_col1" class="data row0 col1" >ERROR</td>
#       <td id="T_f2d2e_row0_col2" class="data row0 col2" >Database connection failed</td>
#     </tr>
#     <tr>
#       <th id="T_f2d2e_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_f2d2e_row1_col0" class="data row1 col0" >2024-01-04</td>
#       <td id="T_f2d2e_row1_col1" class="data row1 col1" >ERROR</td>
#       <td id="T_f2d2e_row1_col2" class="data row1 col2" >Retry attempt failed</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Highlighting with Invert Match
#
# Highlight rows that DON'T match the pattern (like `grep -v`):

# %%
# Highlight rows that DON'T contain 'ERROR'
result = nwgrep(df, "ERROR", invert=True, highlight=True)
result
# Out:
# <style type="text/css">
# </style>
# <table id="T_1e246">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e246_level0_col0" class="col_heading level0 col0" >timestamp</th>
#       <th id="T_1e246_level0_col1" class="col_heading level0 col1" >level</th>
#       <th id="T_1e246_level0_col2" class="col_heading level0 col2" >message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e246_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e246_row0_col0" class="data row0 col0" >2024-01-01</td>
#       <td id="T_1e246_row0_col1" class="data row0 col1" >INFO</td>
#       <td id="T_1e246_row0_col2" class="data row0 col2" >Application started</td>
#     </tr>
#     <tr>
#       <th id="T_1e246_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_1e246_row1_col0" class="data row1 col0" >2024-01-03</td>
#       <td id="T_1e246_row1_col1" class="data row1 col1" >WARN</td>
#       <td id="T_1e246_row1_col2" class="data row1 col2" >Slow query detected</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Multiple Patterns
#
# Highlight rows matching any of multiple patterns (OR logic):

# %%
# Highlight rows with 'ERROR' OR 'WARN'
result = nwgrep(df, ["ERROR", "WARN"], highlight=True)
result
# Out:
# <style type="text/css">
# #T_c93f2_row0_col1, #T_c93f2_row1_col1, #T_c93f2_row2_col1 {
#   background-color: #ffff99;
# }
# </style>
# <table id="T_c93f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c93f2_level0_col0" class="col_heading level0 col0" >timestamp</th>
#       <th id="T_c93f2_level0_col1" class="col_heading level0 col1" >level</th>
#       <th id="T_c93f2_level0_col2" class="col_heading level0 col2" >message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c93f2_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c93f2_row0_col0" class="data row0 col0" >2024-01-02</td>
#       <td id="T_c93f2_row0_col1" class="data row0 col1" >ERROR</td>
#       <td id="T_c93f2_row0_col2" class="data row0 col2" >Database connection failed</td>
#     </tr>
#     <tr>
#       <th id="T_c93f2_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c93f2_row1_col0" class="data row1 col0" >2024-01-03</td>
#       <td id="T_c93f2_row1_col1" class="data row1 col1" >WARN</td>
#       <td id="T_c93f2_row1_col2" class="data row1 col2" >Slow query detected</td>
#     </tr>
#     <tr>
#       <th id="T_c93f2_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c93f2_row2_col0" class="data row2 col0" >2024-01-04</td>
#       <td id="T_c93f2_row2_col1" class="data row2 col1" >ERROR</td>
#       <td id="T_c93f2_row2_col2" class="data row2 col2" >Retry attempt failed</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Notes
#
# - The `highlight=True` parameter returns a `pandas.Styler` object with yellow background on matching rows
# - Pandas highlighting uses the built-in `pandas.Styler` and requires no additional dependencies
# - The highlighting is compatible with all other nwgrep options (regex, case sensitivity, column filtering, etc.)
# - The `highlight` parameter is incompatible with `count=True` (will raise a `ValueError`)
