# %% [markdown]
# # nwgrep Highlighting with Polars
#
# This notebook demonstrates highlighting matching rows in polars DataFrames using `nwgrep`.
#
# When `highlight=True`, nwgrep returns a Great Tables `GT` object that displays matching rows with a yellow background in Jupyter notebooks.
#
# **Note:** Highlighting with polars requires the `great-tables` library. Install with:
# ```bash
# pip install 'nwgrep[notebook]'
# ```

# %%
from __future__ import annotations

import polars as pl

from nwgrep import nwgrep, register_grep_accessor

# Create sample dataframe
df = pl.DataFrame({
    "timestamp": ["2024-01-01", "2024-01-02", "2024-01-03", "2024-01-04"],
    "level": ["INFO", "ERROR", "WARN", "ERROR"],
    "message": ["Application started", "Database connection failed", "Slow query detected", "Retry attempt failed"]
})

print("Original DataFrame:")
df
# Out:
# Original DataFrame:
# shape: (4, 3)
# ┌────────────┬───────┬────────────────────────────┐
# │ timestamp  ┆ level ┆ message                    │
# │ ---        ┆ ---   ┆ ---                        │
# │ str        ┆ str   ┆ str                        │
# ╞════════════╪═══════╪════════════════════════════╡
# │ 2024-01-01 ┆ INFO  ┆ Application started        │
# │ 2024-01-02 ┆ ERROR ┆ Database connection failed │
# │ 2024-01-03 ┆ WARN  ┆ Slow query detected        │
# │ 2024-01-04 ┆ ERROR ┆ Retry attempt failed       │
# └────────────┴───────┴────────────────────────────┘

# %% [markdown]
# ## Basic Highlighting
#
# Highlight rows containing "ERROR" with a yellow background:

# %%
# Highlight matching rows
result = nwgrep(df, "ERROR", highlight=True)
result
# Out:
# GT(_tbl_data=shape: (2, 3)
# ┌────────────┬───────┬────────────────────────────┐
# │ timestamp  ┆ level ┆ message                    │
# │ ---        ┆ ---   ┆ ---                        │
# │ str        ┆ str   ┆ str                        │
# ╞════════════╪═══════╪════════════════════════════╡
# │ 2024-01-02 ┆ ERROR ┆ Database connection failed │
# │ 2024-01-04 ┆ ERROR ┆ Retry attempt failed       │
# └────────────┴───────┴────────────────────────────┘, _body=<great_tables._gt_data.Body object at 0x107359400>, _boxhead=Boxhead([ColInfo(var='timestamp', type=<ColInfoTypeEnum.default: 1>, column_label='timestamp', column_align='left', column_width=None), ColInfo(var='level', type=<ColInfoTypeEnum.default: 1>, column_label='level', column_align='left', column_width=None), ColInfo(var='message', type=<ColInfoTypeEnum.default: 1>, column_label='message', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x107358ec0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x107359550>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x107345bd0>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='level', rows=[0, 1], mask=None), grpname=None, colname='level', rownum=0, colnum=None, styles=[CellStyleFill(color='#ffff99')]), StyleInfo(locname=LocBody(columns='level', rows=[0, 1], mask=None), grpname=None, colname='level', rownum=1, colnum=None, styles=[CellStyleFill(color='#ffff99')])], _locale=<great_tables._gt_data.Locale object at 0x1073596a0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading ...

# %% [markdown]
# ## Highlighting with Case-Insensitive Search
#
# Highlight rows with case-insensitive matching:

# %%
# Case-insensitive highlighting
result = nwgrep(df, "error", case_sensitive=False, highlight=True)
result
# Out:
# GT(_tbl_data=shape: (2, 3)
# ┌────────────┬───────┬────────────────────────────┐
# │ timestamp  ┆ level ┆ message                    │
# │ ---        ┆ ---   ┆ ---                        │
# │ str        ┆ str   ┆ str                        │
# ╞════════════╪═══════╪════════════════════════════╡
# │ 2024-01-02 ┆ ERROR ┆ Database connection failed │
# │ 2024-01-04 ┆ ERROR ┆ Retry attempt failed       │
# └────────────┴───────┴────────────────────────────┘, _body=<great_tables._gt_data.Body object at 0x1073b0c30>, _boxhead=Boxhead([ColInfo(var='timestamp', type=<ColInfoTypeEnum.default: 1>, column_label='timestamp', column_align='left', column_width=None), ColInfo(var='level', type=<ColInfoTypeEnum.default: 1>, column_label='level', column_align='left', column_width=None), ColInfo(var='message', type=<ColInfoTypeEnum.default: 1>, column_label='message', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x107346710>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x107346d50>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x1073b0b00>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='level', rows=[0, 1], mask=None), grpname=None, colname='level', rownum=0, colnum=None, styles=[CellStyleFill(color='#ffff99')]), StyleInfo(locname=LocBody(columns='level', rows=[0, 1], mask=None), grpname=None, colname='level', rownum=1, colnum=None, styles=[CellStyleFill(color='#ffff99')])], _locale=<great_tables._gt_data.Locale object at 0x107346e90>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading ...

# %% [markdown]
# ## Highlighting with Regex Patterns
#
# Highlight rows matching a regex pattern:

# %%
# Highlight rows with dates
result = nwgrep(df, r"\d{4}-\d{2}-\d{2}", regex=True, highlight=True)
result
# Out:
# GT(_tbl_data=shape: (4, 3)
# ┌────────────┬───────┬────────────────────────────┐
# │ timestamp  ┆ level ┆ message                    │
# │ ---        ┆ ---   ┆ ---                        │
# │ str        ┆ str   ┆ str                        │
# ╞════════════╪═══════╪════════════════════════════╡
# │ 2024-01-01 ┆ INFO  ┆ Application started        │
# │ 2024-01-02 ┆ ERROR ┆ Database connection failed │
# │ 2024-01-03 ┆ WARN  ┆ Slow query detected        │
# │ 2024-01-04 ┆ ERROR ┆ Retry attempt failed       │
# └────────────┴───────┴────────────────────────────┘, _body=<great_tables._gt_data.Body object at 0x1073a4f30>, _boxhead=Boxhead([ColInfo(var='timestamp', type=<ColInfoTypeEnum.default: 1>, column_label='timestamp', column_align='left', column_width=None), ColInfo(var='level', type=<ColInfoTypeEnum.default: 1>, column_label='level', column_align='left', column_width=None), ColInfo(var='message', type=<ColInfoTypeEnum.default: 1>, column_label='message', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x105225590>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x1073b1350>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x1073e4950>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='timestamp', rows=[0, 1, 2, 3], mask=None), grpname=None, colname='timestamp', rownum=0, colnum=None, styles=[CellStyleFill(color='#ffff99')]), StyleInfo(locname=LocBody(columns='timestamp', rows=[0, 1, 2, 3], mask=None), grpname=None, colname='timestamp', rownum=1, colnum=None, styles=[CellStyleFill(color='#ffff99')]), StyleInfo(locname=LocBody(columns='timestamp', rows=[0, 1, 2, 3], mask=None), grpname=None, colname='timestamp', rownum=2, colnum=None, styles=[CellStyleFill(color='#ffff99')]), StyleInfo(locname=LocBody(columns='timestamp', rows=[0, 1, 2, 3], mask=None), grpname=None, colname='timestamp', rownum=3, colnum=None, styles=[CellStyleFill(color='#ffff99')])], _locale=<great_tables._gt_data.Locale object at 0x1052fdd10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), tab ...

# %% [markdown]
# ## Highlighting with Column Filtering
#
# Highlight rows where only specific columns match:

# %%
# Only search in the 'message' column
result = nwgrep(df, "connection", case_sensitive=False, columns=["message"], highlight=True)
result
# Out:
# GT(_tbl_data=shape: (1, 3)
# ┌────────────┬───────┬────────────────────────────┐
# │ timestamp  ┆ level ┆ message                    │
# │ ---        ┆ ---   ┆ ---                        │
# │ str        ┆ str   ┆ str                        │
# ╞════════════╪═══════╪════════════════════════════╡
# │ 2024-01-02 ┆ ERROR ┆ Database connection failed │
# └────────────┴───────┴────────────────────────────┘, _body=<great_tables._gt_data.Body object at 0x107393650>, _boxhead=Boxhead([ColInfo(var='timestamp', type=<ColInfoTypeEnum.default: 1>, column_label='timestamp', column_align='left', column_width=None), ColInfo(var='level', type=<ColInfoTypeEnum.default: 1>, column_label='level', column_align='left', column_width=None), ColInfo(var='message', type=<ColInfoTypeEnum.default: 1>, column_label='message', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x1073b10f0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x1073a59d0>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x1073a5bf0>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='message', rows=[0], mask=None), grpname=None, colname='message', rownum=0, colnum=None, styles=[CellStyleFill(color='#ffff99')])], _locale=<great_tables._gt_data.Locale object at 0x1073b1810>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', valu ...

# %% [markdown]
# ## Using the Accessor
#
# You can also use the `.grep()` accessor with highlighting:

# %%
# Register the accessor
register_grep_accessor()

# Use df.grep() with highlighting
df.grep("failed", case_sensitive=False, highlight=True)
# Out:
# GT(_tbl_data=shape: (2, 3)
# ┌────────────┬───────┬────────────────────────────┐
# │ timestamp  ┆ level ┆ message                    │
# │ ---        ┆ ---   ┆ ---                        │
# │ str        ┆ str   ┆ str                        │
# ╞════════════╪═══════╪════════════════════════════╡
# │ 2024-01-02 ┆ ERROR ┆ Database connection failed │
# │ 2024-01-04 ┆ ERROR ┆ Retry attempt failed       │
# └────────────┴───────┴────────────────────────────┘, _body=<great_tables._gt_data.Body object at 0x10e50ab30>, _boxhead=Boxhead([ColInfo(var='timestamp', type=<ColInfoTypeEnum.default: 1>, column_label='timestamp', column_align='left', column_width=None), ColInfo(var='level', type=<ColInfoTypeEnum.default: 1>, column_label='level', column_align='left', column_width=None), ColInfo(var='message', type=<ColInfoTypeEnum.default: 1>, column_label='message', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x10e4ae190>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x10e554750>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x10e554d50>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='message', rows=[0, 1], mask=None), grpname=None, colname='message', rownum=0, colnum=None, styles=[CellStyleFill(color='#ffff99')]), StyleInfo(locname=LocBody(columns='message', rows=[0, 1], mask=None), grpname=None, colname='message', rownum=1, colnum=None, styles=[CellStyleFill(color='#ffff99')])], _locale=<great_tables._gt_data.Locale object at 0x10e4ae780>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), ...

# %% [markdown]
# ## Highlighting with Invert Match
#
# Highlight rows that DON'T match the pattern (like `grep -v`):

# %%
# Highlight rows that DON'T contain 'ERROR'
result = nwgrep(df, "ERROR", invert=True, highlight=True)
result
# Out:
# GT(_tbl_data=shape: (2, 3)
# ┌────────────┬───────┬─────────────────────┐
# │ timestamp  ┆ level ┆ message             │
# │ ---        ┆ ---   ┆ ---                 │
# │ str        ┆ str   ┆ str                 │
# ╞════════════╪═══════╪═════════════════════╡
# │ 2024-01-01 ┆ INFO  ┆ Application started │
# │ 2024-01-03 ┆ WARN  ┆ Slow query detected │
# └────────────┴───────┴─────────────────────┘, _body=<great_tables._gt_data.Body object at 0x104da74d0>, _boxhead=Boxhead([ColInfo(var='timestamp', type=<ColInfoTypeEnum.default: 1>, column_label='timestamp', column_align='left', column_width=None), ColInfo(var='level', type=<ColInfoTypeEnum.default: 1>, column_label='level', column_align='left', column_width=None), ColInfo(var='message', type=<ColInfoTypeEnum.default: 1>, column_label='message', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x10e48b0b0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x10e54ae40>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x10e54b020>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x10e48b530>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='headi ...

# %% [markdown]
# ## Multiple Patterns
#
# Highlight rows matching any of multiple patterns (OR logic):

# %%
# Highlight rows with 'ERROR' OR 'WARN'
result = nwgrep(df, ["ERROR", "WARN"], highlight=True)
result
# Out:
# GT(_tbl_data=shape: (3, 3)
# ┌────────────┬───────┬────────────────────────────┐
# │ timestamp  ┆ level ┆ message                    │
# │ ---        ┆ ---   ┆ ---                        │
# │ str        ┆ str   ┆ str                        │
# ╞════════════╪═══════╪════════════════════════════╡
# │ 2024-01-02 ┆ ERROR ┆ Database connection failed │
# │ 2024-01-03 ┆ WARN  ┆ Slow query detected        │
# │ 2024-01-04 ┆ ERROR ┆ Retry attempt failed       │
# └────────────┴───────┴────────────────────────────┘, _body=<great_tables._gt_data.Body object at 0x1073b9de0>, _boxhead=Boxhead([ColInfo(var='timestamp', type=<ColInfoTypeEnum.default: 1>, column_label='timestamp', column_align='left', column_width=None), ColInfo(var='level', type=<ColInfoTypeEnum.default: 1>, column_label='level', column_align='left', column_width=None), ColInfo(var='message', type=<ColInfoTypeEnum.default: 1>, column_label='message', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x10e52de10>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x10e50b930>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x10e50b850>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='level', rows=[0, 1, 2], mask=None), grpname=None, colname='level', rownum=0, colnum=None, styles=[CellStyleFill(color='#ffff99')]), StyleInfo(locname=LocBody(columns='level', rows=[0, 1, 2], mask=None), grpname=None, colname='level', rownum=1, colnum=None, styles=[CellStyleFill(color='#ffff99')]), StyleInfo(locname=LocBody(columns='level', rows=[0, 1, 2], mask=None), grpname=None, colname='level', rownum=2, colnum=None, styles=[CellStyleFill(color='#ffff99')])], _locale=<great_tables._gt_data.Locale object at 0x10e52e250>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_wid ...

# %% [markdown]
# ## Highlighting with LazyFrames
#
# Highlighting works with Polars LazyFrames too (automatically collected):

# %%
# Create a lazy frame
lazy_df = pl.scan_csv("your_file.csv")  # or create lazy from df.lazy()
lazy_df = df.lazy()

# Highlighting automatically collects the LazyFrame
result = nwgrep(lazy_df, "ERROR", highlight=True)
result
# Out:
# GT(_tbl_data=shape: (2, 3)
# ┌────────────┬───────┬────────────────────────────┐
# │ timestamp  ┆ level ┆ message                    │
# │ ---        ┆ ---   ┆ ---                        │
# │ str        ┆ str   ┆ str                        │
# ╞════════════╪═══════╪════════════════════════════╡
# │ 2024-01-02 ┆ ERROR ┆ Database connection failed │
# │ 2024-01-04 ┆ ERROR ┆ Retry attempt failed       │
# └────────────┴───────┴────────────────────────────┘, _body=<great_tables._gt_data.Body object at 0x10e4c7920>, _boxhead=Boxhead([ColInfo(var='timestamp', type=<ColInfoTypeEnum.default: 1>, column_label='timestamp', column_align='left', column_width=None), ColInfo(var='level', type=<ColInfoTypeEnum.default: 1>, column_label='level', column_align='left', column_width=None), ColInfo(var='message', type=<ColInfoTypeEnum.default: 1>, column_label='message', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x10e52dae0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x10e570530>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x10e540650>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='level', rows=[0, 1], mask=None), grpname=None, colname='level', rownum=0, colnum=None, styles=[CellStyleFill(color='#ffff99')]), StyleInfo(locname=LocBody(columns='level', rows=[0, 1], mask=None), grpname=None, colname='level', rownum=1, colnum=None, styles=[CellStyleFill(color='#ffff99')])], _locale=<great_tables._gt_data.Locale object at 0x10e52e690>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading ...

# %% [markdown]
# ## Notes
#
# - The `highlight=True` parameter returns a `great_tables.GT` object with yellow background on matching rows
# - Polars highlighting requires the `great-tables` library (install with `pip install 'nwgrep[notebook]'`)
# - The highlighting is compatible with all other nwgrep options (regex, case sensitivity, column filtering, etc.)
# - The `highlight` parameter is incompatible with `count=True` (will raise a `ValueError`)
# - LazyFrames are automatically collected when highlighting is requested
